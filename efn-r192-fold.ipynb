# %%
from timm.models import create_model
import torch
import torch.nn as nn

# %%
ckpt=torch.load('./r192_a70_pth.tar',map_location=torch.device('cpu'))

# %%
def fold_parameter(conv_layer, bn_layer):
    bn_gamma = bn_layer.weight.data
    bn_beta = bn_layer.bias.data
    bn_mean = bn_layer.running_mean
    bn_var = bn_layer.running_var
    eps = bn_layer.eps
    fold_factor = bn_gamma/torch.sqrt(bn_var+eps)
    fold_bias = bn_beta-bn_mean*fold_factor
    fold_factor = torch.unsqueeze(fold_factor,1)
    fold_factor = torch.unsqueeze(fold_factor,2)
    fold_factor = torch.unsqueeze(fold_factor,3)
    fold_weight = conv_layer.weight.data*fold_factor
    conv_layer.weight.data = fold_weight
    conv_layer.bias = nn.Parameter(fold_bias)

# %%
model = torch.load('./efn_r192.pth')

# %%
model.load_state_dict(ckpt['state_dict'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Fold all batch norm layer

# %%
# fold conv_stem
fold_parameter(model.conv_stem,model.bn1)
model.bn1 = nn.Identity()
# fold blocks
for blocks in model.blocks:
    for b in blocks:
        if hasattr(b, 'conv_pwl'):
            fold_parameter(b.conv_pw,b.bn1)
            b.bn1 = nn.Identity()
            fold_parameter(b.conv_dw,b.bn2)
            b.bn2 = nn.Identity()
            fold_parameter(b.conv_pwl,b.bn3)
            b.bn3 = nn.Identity()
        else:
            fold_parameter(b.conv_dw,b.bn1)
            b.bn1 = nn.Identity()
            fold_parameter(b.conv_pw,b.bn2)
            b.bn2 = nn.Identity()
    
fold_parameter(model.conv_head,model.bn2)
model.bn2 = nn.Identity()

# %%
torch.save(model, 'efn-r192-fold.pth')

# %%
model
# Out:
# EfficientNet(
#   (conv_stem): Conv2dSame(3, 32, kernel_size=(3, 3), stride=(2, 2))
#   (bn1): Identity()
#   (act1): ReLU6(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_pw): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): Identity()
#         (act2): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2dSame(96, 96, kernel_size=(3, 3), stride=(2, 2), groups=96)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#     )
#     (2): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2dSame(96, 96, kernel_size=(5, 5), stride=(2, 2), groups=96)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2d(192, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=192)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2dSame(192, 192, kernel_size=(3, 3), stride=(2, 2), groups=192)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(192, 56, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2d(336, 336, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=336)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2d(336, 336, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=336)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2d(336, 336, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=336)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(336, 80, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2dSame(480, 480, kernel_size=(5, 5), stride=(2, 2), groups=480)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2d(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2d(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2d(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#     )
#     (6): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): Identity()
#         (act1): ReLU6(inplace=True)
#         (conv_dw): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768)
#         (bn2): Identity()
#         (act2): ReLU6(inplace=True)
#         (conv_pwl): Conv2d(768, 216, kernel_size=(1, 1), stride=(1, 1))
#         (bn3): Identity()
#       )
#     )
#   )
#   (conv_head): Conv2d(216, 1280, kernel_size=(1, 1), stride=(1, 1))
#   (bn2): Identity()
#   (act2): ReLU6(inplace=True)
#   (global_pool): SelectAdaptivePool2d (output_size=1, pool_type=avg)
#   (classifier): Linear(in_features=1280, out_features=1000, bias=True)
# )
